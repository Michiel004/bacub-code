# %%
from numpy import *

# %%
from matplotlib.pyplot import *

# %%
from control.matlab import *

# %%
sys = tf(1, [1, 2, 1, 0])

# %%
 gm, pm, wg, wp = margin(sys)

# %%
mag, phase, omega = bode(sys)
# Out:
# /home/gebruiker/anaconda3/lib/python3.6/site-packages/control/freqplot.py:153: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True);
# /home/gebruiker/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:911: MatplotlibDeprecationWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   mplDeprecation)
# /home/gebruiker/anaconda3/lib/python3.6/site-packages/matplotlib/rcsetup.py:156: MatplotlibDeprecationWarning: axes.hold is deprecated, will be removed in 3.0
#   mplDeprecation)
# /home/gebruiker/anaconda3/lib/python3.6/site-packages/control/freqplot.py:163: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True);

# %%
real, imag, freq = nyquist_plot(sys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0d16d35f0cf0> in <module>()
# ----> 1 real, imag, freq = nyquist_plot(sys)
#
# NameError: name 'nyquist_plot' is not defined

# %%
import matplotlib.pyplot as plt

# %%
import control.matlab as plt

# %%
real, imag, freq = nyquist_plot(sys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0d16d35f0cf0> in <module>()
# ----> 1 real, imag, freq = nyquist_plot(sys)
#
# NameError: name 'nyquist_plot' is not defined

# %%
real, imag, freq = plt.nyquist_plot(sys)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-c27b9c19e60a> in <module>()
# ----> 1 real, imag, freq = plt.nyquist_plot(sys)
#
# AttributeError: module 'control.matlab' has no attribute 'nyquist_plot'

# %%
import control as cnt

# %%
sys = cnt.tf([10],[2,1])

# %%
cnt.rlocus(sys)
# Out:
# (array([[-2.00149589e+00 +0.j        , -9.95995932e-01 +0.j        ,
#          -2.50817443e-03 +0.j        ],
#         [-2.00198136e+00 +0.j        , -9.94689965e-01 +0.j        ,
#          -3.32867365e-03 +0.j        ],
#         [-2.00262363e+00 +0.j        , -9.92957230e-01 +0.j        ,
#          -4.41914331e-03 +0.j        ],
#         [-2.00347277e+00 +0.j        , -9.90657610e-01 +0.j        ,
#          -5.86961909e-03 +0.j        ],
#         [-2.00459446e+00 +0.j        , -9.87604433e-01 +0.j        ,
#          -7.80110937e-03 +0.j        ],
#         [-2.00607447e+00 +0.j        , -9.83548520e-01 +0.j        ,
#          -1.03770058e-02 +0.j        ],
#         [-2.00802439e+00 +0.j        , -9.78156293e-01 +0.j        ,
#          -1.38193191e-02 +0.j        ],
#         [-2.01058842e+00 +0.j        , -9.70979274e-01 +0.j        ,
#          -1.84323083e-02 +0.j        ],
#         [-2.01395155e+00 +0.j        , -9.61410535e-01 +0.j        ,
#          -2.46379146e-02 +0.j        ],
#         [-2.01834869e+00 +0.j        , -9.48620276e-01 +0.j        ,
#          -3.30310380e-02 +0.j        ],
#         [-2.02407432e+00 +0.j        , -9.31455252e-01 +0.j        ,
#          -4.44704322e-02 +0.j        ],
#         [-2.03149171e+00 +0.j        , -9.08269091e-01 +0.j        ,
#          -6.02391993e-02 +0.j        ],
#         [-2.04104005e+00 +0.j        , -8.76602367e-01 +0.j        ,
#          -8.23575832e-02 +0.j        ],
#         [-2.05323736e+00 +0.j        , -8.32475884e-01 +0.j        ,
#          -1.14286760e-01 +0.j        ],
#         [-2.06867685e+00 +0.j        , -7.68403377e-01 +0.j        ,
#          -1.62919774e-01 +0.j        ],
#         -3.1858966 , -2.84718176, -2.52807828, -2.2333168 , -1.96507977,
#         -1.72373333, -1.50844186, -1.31764072, -1.14937692, -1.00154175,
#         -0.87202147, -0.75878913, -0.65995598, -0.57379598, -0.49875312]),
#  array([ 0.01      ,  0.01151395,  0.01325711,  0.01526418,  0.01757511,
#          0.0202359 ,  0.02329952,  0.02682696,  0.03088844,  0.0355648 ,
#          0.04094915,  0.04714866,  0.05428675,  0.06250552,  0.07196857,
#          0.08286428,  0.09540955,  0.10985411,  0.12648552,  0.14563485,
#          0.16768329,  0.19306977,  0.22229965,  0.25595479,  0.29470517,
#          0.33932218,  0.39069399,  0.44984327,  0.51794747,  0.59636233,
#          0.68664885,  0.79060432,  0.91029818,  1.04811313,  1.20679264,
#          1.38949549,  1.59985872,  1.84206997,  2.12095089,  2.44205309,
#          2.8117687 ,  3.23745754,  3.72759372,  4.29193426,  4.94171336,
#          5.68986603,  6.55128557,  7.54312006,  8.68511374, 10.        ]))

# %%
cnt.bode(sys)
# Out:
# /home/gebruiker/anaconda3/lib/python3.6/site-packages/control/freqplot.py:153: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True);
# /home/gebruiker/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:911: MatplotlibDeprecationWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   mplDeprecation)
# /home/gebruiker/anaconda3/lib/python3.6/site-packages/matplotlib/rcsetup.py:156: MatplotlibDeprecationWarning: axes.hold is deprecated, will be removed in 3.0
#   mplDeprecation)
# /home/gebruiker/anaconda3/lib/python3.6/site-packages/control/freqplot.py:163: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True);
# (array([9.9980006 , 9.99734963, 9.99648683, 9.99534335, 9.99382803,
#         9.99182022, 9.9891603 , 9.98563729, 9.98097254, 9.97479848,
#         9.96663111, 9.95583439, 9.94157501, 9.92276529, 9.89799283,
#         9.86543592, 9.82276601, 9.76704229, 9.69460992, 9.60102384,
#         9.48103391, 9.32868394, 9.13759026, 8.90146471, 8.61491497,
#         8.27447737, 7.87971621, 7.43410008, 6.94531816, 6.4248035 ,
#         5.88648252, 5.34505627, 4.81427823, 4.30564187, 3.82768455,
#         3.38588551, 2.9829899 , 2.61955306, 2.29453593, 2.0058458 ,
#         1.75077463, 1.52632581, 1.32944146, 1.15715013, 1.00665523,
#         0.87538192, 0.76099585, 0.66140424, 0.57474605, 0.49937617]),
#  array([ -1.14576284,  -1.31916879,  -1.51879748,  -1.74860306,
#          -2.01313   ,  -2.3175981 ,  -2.66799806,  -3.07119813,
#          -3.53506155,  -4.06857392,  -4.68197781,  -5.38690978,
#          -6.19653123,  -7.12563908,  -8.19073455,  -9.4100171 ,
#         -10.80325581, -12.39147203, -14.19634595, -16.23924089,
#         -18.53973198, -21.11354654, -23.96989743, -27.10834181,
#         -30.51553718, -34.16255543, -38.00364166, -41.97728814,
#         -46.01007927, -50.0229774 , -53.93885737, -57.68960957,
#         -61.22130305, -64.49662979, -67.49472706, -70.20909572,
#         -72.6445349 , -74.81388522, -76.73509539, -78.42885425,
#         -79.91683398, -81.22048055, -82.3602434 , -83.3551324 ,
#         -84.22250445, -84.97800323, -85.63559556, -86.20766443,
#         -86.70513198, -87.13759477]),
#  array([ 0.01      ,  0.01151395,  0.01325711,  0.01526418,  0.01757511,
#          0.0202359 ,  0.02329952,  0.02682696,  0.03088844,  0.0355648 ,
#          0.04094915,  0.04714866,  0.05428675,  0.06250552,  0.07196857,
#          0.08286428,  0.09540955,  0.10985411,  0.12648552,  0.14563485,
#          0.16768329,  0.19306977,  0.22229965,  0.25595479,  0.29470517,
#          0.33932218,  0.39069399,  0.44984327,  0.51794747,  0.59636233,
#          0.68664885,  0.79060432,  0.91029818,  1.04811313,  1.20679264,
#          1.38949549,  1.59985872,  1.84206997,  2.12095089,  2.44205309,
#          2.8117687 ,  3.23745754,  3.72759372,  4.29193426,  4.94171336,
#          5.68986603,  6.55128557,  7.54312006,  8.68511374, 10.        ]))

# %%
cnt.nichols_plot(sys)

# %%
cnt.step_response(sys)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/control/statesp.py in _convertToStateSpace(sys, **kw)
#     640         try:
# --> 641             from slycot import td04ad
#     642             if len(kw):
#
# ModuleNotFoundError: No module named 'slycot'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-f61a112173e4> in <module>()
# ----> 1 cnt.step_response(sys)
#
# ~/anaconda3/lib/python3.6/site-packages/control/timeresp.py in step_response(sys, T, X0, input, output, transpose, **keywords)
#     481     >>> T, yout = step_response(sys, T, X0)
#     482     """
# --> 483     sys = _get_ss_simo(sys, input, output)
#     484     if T is None:
#     485         if isctime(sys):
#
# ~/anaconda3/lib/python3.6/site-packages/control/timeresp.py in _get_ss_simo(sys, input, output)
#     407     If input is not specified, select first input and issue warning
#     408     """
# --> 409     sys_ss = _convertToStateSpace(sys)
#     410     if sys_ss.issiso():
#     411         return sys_ss
#
# ~/anaconda3/lib/python3.6/site-packages/control/statesp.py in _convertToStateSpace(sys, **kw)
#     666             # the squeeze
#     667             lti_sys = lti(squeeze(sys.num), squeeze(sys.den))
# --> 668             return StateSpace(lti_sys.A, lti_sys.B, lti_sys.C, lti_sys.D,
#     669                               sys.dt)
#     670
#
# AttributeError: 'TransferFunctionContinuous' object has no attribute 'A'

# %%
T, yout = cnt.step_response(sys, T, X0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-6a6dfd9bad0e> in <module>()
# ----> 1 T, yout = cnt.step_response(sys, T, X0)
#
# NameError: name 'T' is not defined

# %%
cnt.pole(sys)
# Out:
# array([-0.5])

# %%
cnt.zero(sys)
# Out:
# array([], dtype=float64)

# %%
cnt.pzmap(sys)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-17566d592253> in <module>()
# ----> 1 cnt.pzmap(sys)
#
# TypeError: 'module' object is not callable

# %%
cnt.root_locus(sys)
# Out:
# (array([[-5.05000000e-01],
#         [-5.06628557e-01],
#         [-5.08787553e-01],
#         [-5.11649759e-01],
#         [-5.15444218e-01],
#         [-5.20474575e-01],
#         [-5.27143377e-01],
#         [-5.35984284e-01],
#         [-5.47704774e-01],
#         [-5.63242761e-01],
#         [-5.83841647e-01],
#         [-6.11149824e-01],
#         [-6.47352585e-01],
#         [-6.95346997e-01],
#         [-7.58973734e-01],
#         [-8.43324423e-01],
#         [-9.55149089e-01],
#         [-1.10339632e+00],
#         [-1.29992936e+00],
#         [-1.56047544e+00],
#         [-1.90588435e+00],
#         [-2.36379686e+00],
#         [-2.97085668e+00],
#         [-3.77564278e+00],
#         [-4.84255687e+00],
#         [-6.25697700e+00],
#         [-8.13208984e+00],
#         [-1.06179482e+01],
#         [-1.39134790e+01],
#         [-1.82824015e+01],
#         [-2.40743318e+01],
#         [-3.17527596e+01],
#         [-4.19321386e+01],
#         [-5.54270571e+01],
#         [-7.33174239e+01],
#         [-9.70348864e+01],
#         [-1.28477396e+02],
#         [-1.70161089e+02],
#         [-2.25421633e+02],
#         [-2.98681166e+02],
#         [-3.95802161e+02],
#         [-5.24556567e+02],
#         [-6.95247747e+02],
#         [-9.21534985e+02],
#         [-1.22152655e+03],
#         [-1.61922877e+03],
#         [-2.14646713e+03],
#         [-2.84543301e+03],
#         [-3.77206003e+03],
#         [-5.00050000e+03]]),
#  array([1.00000000e-03, 1.32571137e-03, 1.75751062e-03, 2.32995181e-03,
#         3.08884360e-03, 4.09491506e-03, 5.42867544e-03, 7.19685673e-03,
#         9.54095476e-03, 1.26485522e-02, 1.67683294e-02, 2.22299648e-02,
#         2.94705170e-02, 3.90693994e-02, 5.17947468e-02, 6.86648845e-02,
#         9.10298178e-02, 1.20679264e-01, 1.59985872e-01, 2.12095089e-01,
#         2.81176870e-01, 3.72759372e-01, 4.94171336e-01, 6.55128557e-01,
#         8.68511374e-01, 1.15139540e+00, 1.52641797e+00, 2.02358965e+00,
#         2.68269580e+00, 3.55648031e+00, 4.71486636e+00, 6.25055193e+00,
#         8.28642773e+00, 1.09854114e+01, 1.45634848e+01, 1.93069773e+01,
#         2.55954792e+01, 3.39322177e+01, 4.49843267e+01, 5.96362332e+01,
#         7.90604321e+01, 1.04811313e+02, 1.38949549e+02, 1.84206997e+02,
#         2.44205309e+02, 3.23745754e+02, 4.29193426e+02, 5.68986603e+02,
#         7.54312006e+02, 1.00000000e+03]))

# %%
cnt.dcgain(sys)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/control/statesp.py in _convertToStateSpace(sys, **kw)
#     640         try:
# --> 641             from slycot import td04ad
#     642             if len(kw):
#
# ModuleNotFoundError: No module named 'slycot'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-b6481d116c18> in <module>()
# ----> 1 cnt.dcgain(sys)
#
# ~/anaconda3/lib/python3.6/site-packages/control/matlab.py in dcgain(*args)
#    1223     elif len(args) == 1:
#    1224         sys, = args
# -> 1225         sys = ss(sys)
#    1226     else:
#    1227         raise ValueError("Function ``dcgain`` needs either 1, 2, 3 or 4 "
#
# ~/anaconda3/lib/python3.6/site-packages/control/matlab.py in ss(*args)
#     478             return deepcopy(sys)
#     479         elif isinstance(sys, TransferFunction):
# --> 480             return tf2ss(sys)
#     481         else:
#     482             raise TypeError("ss(sys): sys must be a StateSpace or \
#
# ~/anaconda3/lib/python3.6/site-packages/control/matlab.py in tf2ss(*args)
#     762             raise TypeError("tf2ss(sys): sys must be a TransferFunction \
#     763 object.")
# --> 764         return _convertToStateSpace(sys)
#     765     else:
#     766         raise ValueError("Needs 1 or 2 arguments; received %i." % len(args))
#
# ~/anaconda3/lib/python3.6/site-packages/control/statesp.py in _convertToStateSpace(sys, **kw)
#     666             # the squeeze
#     667             lti_sys = lti(squeeze(sys.num), squeeze(sys.den))
# --> 668             return StateSpace(lti_sys.A, lti_sys.B, lti_sys.C, lti_sys.D,
#     669                               sys.dt)
#     670
#
# AttributeError: 'TransferFunctionContinuous' object has no attribute 'A'
